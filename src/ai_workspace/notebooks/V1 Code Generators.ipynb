# %%
import sys
import os
from IPython.display import Image, display
from langgraph.graph import StateGraph
# Add the parent directory to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from agents.engineering_codegen.code_generator import compiled_graph as code_generator
from agents.engineering_codegen.code_generator import QuestionPayload,QuestionPackage

# %% [markdown]
# ## Visualize the graph

# %%
def show_graph_visualization(
    graph: StateGraph, filename: str = "CodeBuilder.png"
) -> None:
    """
    Visualizes the graph and saves it as a PNG image.

    Args:
        graph: The StateGraph instance.
        filename: The filename to save the image.
    """
    try:
        image_bytes = graph.get_graph().draw_mermaid_png()
        display(Image(image_bytes))
    except Exception as error:
        print(f"Graph visualization failed: {error}")
        
show_graph_visualization(code_generator)
# Out:
# Graph visualization failed: Failed to reach https://mermaid.ink/ API while trying to render your graph after 1 retries. To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`

# %% [markdown]
# ## Running the Graph
# The code generator expects input in the form of a Pydantic model named `QuestionPackage`. This model stores all relevant data—including files, metadata, and the input question. All these values are either generated automatically or are optional. The only required field is `QuestionPayload`, which contains the details of the question. Optionally, `QuestionPayload` may also include a solution guide and additional instructions.

# %%
import json
print(json.dumps(QuestionPackage.model_json_schema(), indent=2))
# Out:
# {
#   "$defs": {
#     "FilesData": {
#       "description": "Holds the generated file contents related to a question.",
#       "properties": {
#         "question_html": {
#           "default": "",
#           "title": "Question Html",
#           "type": "string"
#         },
#         "server_js": {
#           "default": "",
#           "title": "Server Js",
#           "type": "string"
#         },
#         "server_py": {
#           "default": "",
#           "title": "Server Py",
#           "type": "string"
#         },
#         "solution_html": {
#           "default": "",
#           "title": "Solution Html",
#           "type": "string"
#         },
#         "metadata": {
#           "default": {},
#           "title": "Metadata",
#           "type": "object"
#         }
#       },
#       "title": "FilesData",
#       "type": "object"
#     },
#     "InitialMetadata": {
#       "properties": {
#         "createdBy": {
#           "title": "Createdby",
#           "type": "string"
#         },
#         "qtype": {
#           "title": "Qtype",
#           "type": "string"
#         },
#         "nSteps": {
#           "title": "Nsteps",
#           "type": "integer"
#         },
#         "updatedBy": {
#           "title": "Updatedby",
#           "type": "string"
#         },
#         "codelang": {
#           "title": "Codelang",
#           "type": "string"
#         },
#         "reviewed": {
#           "enum": [
#             "True",
#             "False"
#           ],
#           "title": "Reviewed",
#           "type": "string"
#         },
#         "ai_generated": {
#           "enum": [
#             "True",
#             "False"
#           ],
#           "title": "Ai Generated",
#           "type": "string"
#         }
#       },
#       "required": [
#         "createdBy",
#         "qtype",
#         "nSteps",
#         "updatedBy",
#         "codelang",
#         "reviewed",
#         "ai_generated"
#       ],
#       "title": "InitialMetadata",
#       "type": "object"
#     },
#     "QuestionMetadata": {
#       "properties": {
#         "title": {
#           "title": "Title",
#           "type": "string"
#         },
#         "question": {
#           "title": "Question",
#           "type": "string"
#         },
#         "stem": {
#           "title": "Stem",
#           "type": "string"
#         },
#         "topic": {
#           "title": "Topic",
#           "type": "string"
#         },
#         "tags": {
#           "items": {
#             "type": "string"
#           },
#           "title": "Tags",
#           "type": "array"
#         },
#         "prereqs": {
#           "items": {
#             "type": "string"
#           },
#           "title": "Prereqs",
#           "type": "array"
#         },
#         "isAdaptive": {
#           "enum": [
#             "True",
#             "False"
#           ],
#           "title": "Isadaptive",
#           "type": "string"
#         }
#       },
#       "required": [
#         "title",
#         "question",
#         "stem",
#         "topic",
#         "tags",
#         "prereqs",
#         "isAdaptive"
#       ],
#       "title": "QuestionMetadata",
#       "type": "object"
#     },
#     "QuestionPayload": {
#       "properties": {
#         "question": {
#           "description": "The complete, standalone question intended for conversion into educational content.",
#           "title": "Question",
#           "type": "string"
#         },
#         "solution_guide": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "A comprehensive, step-by-step explanation detailing the method to solve the question.",
#           "title": "Solution Guide"
#         },
#         "additional_instructions": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": null,
#           "description": "Specific directives or preferences provided by the user regarding the presentation, constraints, or other aspects of the question.",
#           "title": "Additional Instructions"
#         }
#       },
#       "required": [
#         "question"
#       ],
#       "title": "QuestionPayload",
#       "type": "object"
#     }
#   },
#   "description": "Overall package containing the question payload, metadata, and generated files.\n\nThe fields are annotated with reducer functions to merge concurrent updates.",
#   "properties": {
#     "question_payload": {
#       "$ref": "#/$defs/QuestionPayload"
#     },
#     "question_metadata": {
#       "anyOf": [
#         {
#           "$ref": "#/$defs/QuestionMetadata"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null
#     },
#     "files": {
#       "$ref": "#/$defs/FilesData"
#     },
#     "initial_metadata": {
#       "anyOf": [
#         {
#           "$ref": "#/$defs/InitialMetadata"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null
#     }
#   },
#   "required": [
#     "question_payload"
#   ],
#   "title": "QuestionPackage",
#   "type": "object"
# }

# %%
print(json.dumps(QuestionPayload.model_json_schema(), indent=2))
# Out:
# {
#   "properties": {
#     "question": {
#       "description": "The complete, standalone question intended for conversion into educational content.",
#       "title": "Question",
#       "type": "string"
#     },
#     "solution_guide": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "A comprehensive, step-by-step explanation detailing the method to solve the question.",
#       "title": "Solution Guide"
#     },
#     "additional_instructions": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Specific directives or preferences provided by the user regarding the presentation, constraints, or other aspects of the question.",
#       "title": "Additional Instructions"
#     }
#   },
#   "required": [
#     "question"
#   ],
#   "title": "QuestionPayload",
#   "type": "object"
# }

# %%
question_payload = {
        "question": (
            "What is the final velocity of a 2 kg projectile launched at 30 degrees "
            "with an initial speed of 20 m/s after 3 seconds?"
        ),
        "solution_guide": None,
        "additional_instructions": None,
    }

graph_input = QuestionPackage(question_payload=question_payload)
result = await code_generator.ainvoke(graph_input)
# Out:
# Running Adaptive Combine

# %%
print(json.dumps(dict(result.get("question_payload")), indent=2))
print(json.dumps(dict(result.get("files")), indent=2))
# Out:
# {
#   "question": "What is the final velocity of a 2 kg projectile launched at 30 degrees with an initial speed of 20 m/s after 3 seconds?",
#   "solution_guide": null,
#   "additional_instructions": null
# }
# {
#   "question_html": "<pl-question-panel>\n  <p>What is the final velocity of a {{params.mass}} kg projectile launched at {{params.angle}} degrees with an initial speed of {{params.initial_speed}} {{params.unitsSpeed}} after {{params.time}} seconds?</p>\n  <p>Determine the final velocity (in {{params.unitsSpeed}}) of the projectile and its vertical and horizontal components.</p>\n</pl-question-panel>\n\n<pl-number-input answers-name=\"final_velocity\" comparison=\"sigfig\" digits=\"3\" label=\"$v_f=$ (in {{params.unitsSpeed}})\"></pl-number-input>\n<pl-number-input answers-name=\"vx\" comparison=\"sigfig\" digits=\"3\" label=\"Horizontal component of velocity (in {{params.unitsSpeed}})\"></pl-number-input>\n<pl-number-input answers-name=\"vy\" comparison=\"sigfig\" digits=\"3\" label=\"Vertical component of velocity (in {{params.unitsSpeed}})\"></pl-number-input>",
#   "server_js": "const math = require('mathjs');\n\nconst generate = () => {\n    // Define unit systems and their corresponding units\n    const units = {\n        si: {\n            mass: 'kg',\n            angle: 'degrees',\n            time: 's',\n            speed: 'm/s',\n            acceleration: -9.81 // Acceleration due to gravity in m/s^2 (SI units)\n        },\n        uscs: {\n            mass: 'lb',\n            angle: 'degrees',\n            time: 's',\n            speed: 'ft/s',\n            acceleration: -32.2 // Acceleration due to gravity in ft/s^2 (USCS units)\n        }\n    };\n\n    // Randomly select a unit system\n    const unitSystemKeys = Object.keys(units);\n    const selectedUnitSystem = units[unitSystemKeys[math.randomInt(0, unitSystemKeys.length)]];\n\n    // Generate random problem parameters\n    const mass = math.randomInt(1, 100); // Random mass between 1 kg/lb to 100 kg/lb\n    const angle = math.randomInt(0, 90); // Random angle between 0\u00b0 and 90\u00b0\n    const initialSpeed = math.randomInt(10, 100); // Initial speed between 10 and 100 m/s or ft/s\n    const time = math.randomInt(1, 10); // Time between 1 and 10 seconds\n\n    // Calculate horizontal and vertical components of velocity\n    const initialVx = initialSpeed * math.cos(math.unit(angle, 'deg'));\n    const initialVy = initialSpeed * math.sin(math.unit(angle, 'deg'));\n    const finalVy = initialVy + selectedUnitSystem.acceleration * time; // vy = u*sin(theta) + a*t\n    \n    // Calculate the final velocity\n    const finalVelocity = math.sqrt(math.pow(initialVx, 2) + math.pow(finalVy, 2));\n\n    // Return the generated data\n    return {\n        params: {\n            mass: mass,\n            angle: angle,\n            initial_speed: initialSpeed,\n            time: time,\n            unitsSpeed: selectedUnitSystem.speed\n        },\n        correct_answers: {\n            final_velocity: finalVelocity.toFixed(3),\n            vx: initialVx.toFixed(3),\n            vy: finalVy.toFixed(3)\n        },\n        nDigits: 3,  // Define the number of digits after the decimal place.\n        sigfigs: 3   // Define the number of significant figures for the answer.\n    };\n};\n\nmodule.exports = {\n    generate\n};",
#   "server_py": "import numpy as np\nfrom sympy import symbols, sin, cos, degree\nfrom random import uniform\n\n# Sample data structure to demonstrate functionality\nparams = {\n    'mass': 10.0,  # kg\n    'angle': 45.0,  # degrees\n    'initial_speed': 20.0,  # m/s\n    'unitsSpeed': 'm/s',\n    'time': 5.0  # seconds\n}\n\n# Define physical constants\nGRAVITY = 9.81  # m/s\u00b2\n\n# Placeholder function to generate random test problems\n\ndef generate():\n    # 1. Dynamic Parameter Selection\n    angle_rad = np.radians(params['angle'])  # Convert angle to radians\n    initial_speed = params['initial_speed']\n\n    # 2. Compute velocity components\n    vx_initial = initial_speed * cos(angle_rad)  # Horizontal initial velocity\n    vy_initial = initial_speed * sin(angle_rad)  # Vertical initial velocity\n\n    # 3. Calculate final vertical velocity using v = u + at\n    vy_final = vy_initial + (-GRAVITY * params['time'])  # Final vertical velocity\n\n    # 4. Calculate final velocity vector and magnitude\n    final_velocity = np.sqrt(vx_initial**2 + vy_final**2)  # Magnitude of final velocity\n\n    return {\n        'params': {\n            'mass': params['mass'],\n            'angle': params['angle'],\n            'initial_speed': initial_speed,\n            'unitsSpeed': params['unitsSpeed'],\n            'time': params['time'],\n            'vx_initial': round(vx_initial, 3),\n            'vy_initial': round(vy_initial, 3)\n        },\n        'correct_answers': {\n            'final_velocity': round(final_velocity, 3),\n            'vx': round(vx_initial, 3),\n            'vy': round(vy_final, 3)\n        },\n        'nDigits': 3,  # Decimal places.\n        'sigfigs': 3   # Significant figures.\n    }\n\n# Example usage\nresult = generate()\nprint(result)",
#   "solution_html": "<pl-question-panel>\n  <p>What is the final velocity of a {{params.mass}} kg projectile launched at {{params.angle}} degrees with an initial speed of {{params.initial_speed}} {{params.unitsSpeed}} after {{params.time}} seconds?</p>\n  <p>Determine the final velocity (in {{params.unitsSpeed}}) of the projectile and its vertical and horizontal components.</p>\n</pl-question-panel>\n\n<pl-number-input answers-name=\"final_velocity\" comparison=\"sigfig\" digits=\"3\" label=\"$v_f=$ (in {{params.unitsSpeed}})\" required></pl-number-input>\n<pl-number-input answers-name=\"vx\" comparison=\"sigfig\" digits=\"3\" label=\"Horizontal component of velocity (in {{params.unitsSpeed}})\" required></pl-number-input>\n<pl-number-input answers-name=\"vy\" comparison=\"sigfig\" digits=\"3\" label=\"Vertical component of velocity (in {{params.unitsSpeed}})\" required></pl-number-input>\n\n<pl-solution-panel>\n    <pl-hint level=\"1\" data-type=\"text\">\n        To find the final velocity of the projectile, we can use the equations of motion considering both vertical and horizontal components. The final velocity can be calculated as:\n        $$ v_f = \\sqrt{v_{fx}^2 + v_{fy}^2} $$\n    </pl-hint>\n    <pl-hint level=\"2\" data-type=\"text\">\n        The horizontal component of velocity is given by:\n        $$ v_{fx} = v_{initial} \\cdot \\cos(angle) $$\n        where angle is the launch angle.\n    </pl-hint>\n    <pl-hint level=\"3\" data-type=\"text\">\n        The vertical component of velocity right before impact can be calculated using:\n        $$ v_{fy} = v_{initial} \\cdot \\sin(angle) + g \\cdot t $$\n        where g is the acceleration due to gravity and t is the time of flight.\n    </pl-hint>\n    <pl-hint level=\"4\" data-type=\"text\">\n        Plug in the values to compute:\n        <ul>\n            <li>Horizontal Component: $$ v_{fx} = {{params.initial_speed}} \\cdot \\cos({{params.angle}})$$</li>\n            <li>Vertical Component: $$ v_{fy} = {{params.initial_speed}} \\cdot \\sin({{params.angle}}) + g \\cdot {{params.time}}$$</li>\n        </ul>\n    </pl-hint>\n    <pl-hint level=\"5\" data-type=\"text\">\n        Therefore, the final speed is given by:\n        $$ v_f = \\sqrt{({{params.initial_speed}} \\cdot \\cos({{params.angle}}))^2 + ({{params.initial_speed}} \\cdot \\sin({{params.angle}}) + g \\cdot {{params.time}})^2} $$ \n    </pl-hint>\n</pl-solution-panel>",
#   "metadata": {
#     "title": "ProjectileMotionFinalVelocity",
#     "question": "What is the final velocity of a 2 kg projectile launched at 30 degrees with an initial speed of 20 m/s after 3 seconds?",
#     "stem": "Calculating the final velocity of a projectile considering its launch angle and initial speed over time.",
#     "topic": "Physics",
#     "tags": [
#       "Projectile Motion",
#       "Velocity",
#       "Kinematics",
#       "Physics"
#     ],
#     "prereqs": [
#       "Dynamics"
#     ],
#     "isAdaptive": "True"
#   }
# }

# %% [markdown]
# ## Running Multiple questions

# %%
question_payloads = [
    {
        "question": (
            "What is the final velocity of a 2 kg projectile launched at 30 degrees "
            "with an initial speed of 20 m/s after 3 seconds?"
        ),
        "solution_guide": None,
        "additional_instructions": None,
    },
    {
        "question": (
            "A block of mass 5 kg is sliding down a frictionless incline at an angle of 25 degrees. "
            "What is the acceleration of the block?"
        ),
        "solution_guide": None,
        "additional_instructions": None,
    },
    {
        "question": (
            "Calculate the heat required to raise the temperature of 500g of water "
            "from 25°C to 75°C. Assume the specific heat of water is 4.18 J/g°C."
        ),
        "solution_guide": None,
        "additional_instructions": None,
    },
]
tasks = []
for q in question_payloads:
    print(q)
    graph_input = QuestionPackage(question_payload=q)
    tasks.append(code_generator.ainvoke(graph_input))
import asyncio
results = await asyncio.gather(*tasks)
# Out:
# {'question': 'What is the final velocity of a 2 kg projectile launched at 30 degrees with an initial speed of 20 m/s after 3 seconds?', 'solution_guide': None, 'additional_instructions': None}
# {'question': 'A block of mass 5 kg is sliding down a frictionless incline at an angle of 25 degrees. What is the acceleration of the block?', 'solution_guide': None, 'additional_instructions': None}
# {'question': 'Calculate the heat required to raise the temperature of 500g of water from 25°C to 75°C. Assume the specific heat of water is 4.18 J/g°C.', 'solution_guide': None, 'additional_instructions': None}
# Running Adaptive Combine
# Running Adaptive Combine
# Running Adaptive Combine

# %%
for r in results:
    print(json.dumps(dict(r.get("question_payload")), indent=2))
    print(json.dumps(dict(r.get("files")), indent=2))
# Out:
# {
#   "question": "What is the final velocity of a 2 kg projectile launched at 30 degrees with an initial speed of 20 m/s after 3 seconds?",
#   "solution_guide": null,
#   "additional_instructions": null
# }
# {
#   "question_html": "<pl-question-panel>\n  <p> A projectile is launched at an angle of {{params.angle}} degrees with an initial speed of {{params.initial_speed}} {{params.unitsSpeed}}. After {{params.time}} seconds, determine the final velocity (in {{params.unitsSpeed}}) of the projectile.</p>\n</pl-question-panel>\n\n<pl-number-input answers-name=\"final_velocity\" comparison=\"sigfig\" digits=\"3\" label=\"$v_f=$ (in {{params.unitsSpeed}})\"></pl-number-input>",
#   "server_js": "const math = require('mathjs');\n\n/**\n * The SpeedConverter class provides static methods to convert speeds between\n * different units: feet per second (ft/s), meters per second (m/s),\n * miles per hour (mph), and kilometers per hour (km/h).\n */\nclass SpeedConverter {\n    /**\n     * Converts speed from feet per second to miles per hour.\n     * \n     * @param {number} speedFts - The speed in feet per second.\n     * @return {number} The speed in miles per hour.\n     */\n    static ftstoMPH(speedFts) {\n        return speedFts * (3600 / 5280);\n    }\n\n    /**\n     * Converts speed from meters per second to kilometers per hour.\n     * \n     * @param {number} speedMs - The speed in meters per second.\n     * @return {number} The speed in kilometers per hour.\n     */\n    static mstoKmH(speedMs) {\n        return speedMs * (3600 / 1000);\n    }\n\n    /**\n     * Converts speed from miles per hour to feet per second.\n     * \n     * @param {number} speedMPH - The speed in miles per hour.\n     * @return {number} The speed in feet per second.\n     */\n    static mphToFts(speedMPH) {\n        return speedMPH * (5280 / 3600);\n    }\n\n    /**\n     * Converts speed from kilometers per hour to meters per second.\n     * \n     * @param {number} speedKMH - The speed in kilometers per hour.\n     * @return {number} The speed in meters per second.\n     */\n    static kmHtoMs(speedKMH) {\n        return speedKMH * (1000 / 3600);\n    }\n}\n\nconst generate = () => {\n    const unitSystems = {\n        si: {\n            speed: 'km/h',\n            distance: 'm',\n            time: 's',\n            acceleration: 'm/s^2'\n        },\n        uscs: {\n            speed: 'mph',\n            distance: 'ft',\n            time: 's',\n            acceleration: 'ft/s^2'\n        }\n    };\n\n    // Dynamic Parameter Selection\n    const selectedSystem = math.randomInt(0, 2) === 0 ? 'si' : 'uscs';\n    const units = unitSystems[selectedSystem];\n\n    // Value Generation\n    const v0 = math.randomInt(10, 31); // Initial velocity \n    const a = math.randomInt(1, 11); // Acceleration \n    const t = math.randomInt(1, 11); // Time in seconds\n\n    let v0_converted, vf_converted;\n\n    // Converting Initial Velocity based on the selected system\n    switch (selectedSystem) {\n        case \"si\":\n            v0_converted = SpeedConverter.kmHtoMs(v0); // Convert km/h to m/s for SI units\n            break;\n        case \"uscs\":\n            v0_converted = SpeedConverter.mphToFts(v0); // Convert mph to ft/s for USC units\n            break;\n    }\n\n    // 3. Calculating Final Velocity\n    // Using the kinematic equation: Vf = V0 + a * t\n    let vf = v0_converted + a * t;\n\n    // 4. Converting Final Velocity back to the original unit system\n    switch (selectedSystem) {\n        case \"si\":\n            vf_converted = SpeedConverter.mstoKmH(vf); // Convert m/s to km/h for SI units\n            break;\n        case \"uscs\":\n            vf_converted = SpeedConverter.ftstoMPH(vf); // Convert ft/s to mph for USC units\n            break;\n    }\n\n    // 5. Rounding off the final value\n    vf_converted = math.round(vf_converted, 3); // rounding to 3 decimal places\n\n    // Return the structured data\n    return {\n        params: {\n            v: v0,\n            a: a,\n            t: t,\n            unitsSpeed: units.speed,\n            unitsTime: units.time,\n            unitsAcceleration: units.acceleration\n        },\n        correct_answers: {\n            v: vf_converted\n        },\n        nDigits: 3,\n        sigfigs: 3\n    };\n};\n\nmodule.exports = {\n    generate\n};\n\n// Example usage:\nconst result = generate();\nconsole.log(result);",
#   "server_py": "```python\nimport numpy as np\nfrom sympy import symbols, sin, cos, degree\nimport random\n\n# Define the generate function\n\ndef generate():\n    params = {}\n    correct_answers = {}\n\n    # 1. Dynamic Parameter Selection and Value Generation:\n    # Generate a random problem with different units for speed and time\n    units_speed_choices = ['m/s', 'km/h']\n    units_time_choices = ['s', 'min']\n    angle_range = (20, 70)  # Angle in degrees\n    speed_range = (10, 100)  # Initial speed in m/s\n    time_range = (1, 10)  # Time in seconds\n\n    # Randomly select units\n    params['unitsSpeed'] = random.choice(units_speed_choices)\n    params['unitsTime'] = random.choice(units_time_choices)\n\n    # Randomly generate angle, speed, and time\n    params['angle'] = random.uniform(*angle_range)\n    params['initial_speed'] = random.uniform(*speed_range)\n    params['time'] = random.uniform(*time_range)\n\n    # If units are in km/h, make conversion for calculation\n    if params['unitsSpeed'] == 'km/h':\n        initial_speed_m_s = params['initial_speed'] * (1000 / 3600)\n    else:\n        initial_speed_m_s = params['initial_speed']\n\n    # If units are in minutes, convert time to seconds\n    if params['unitsTime'] == 'min':\n        time_seconds = params['time'] * 60\n    else:\n        time_seconds = params['time']\n\n    # 2. Solution Synthesis:\n    # Calculate the horizontal and vertical components of velocity\n    v_initial_x = initial_speed_m_s * cos(degree(params['angle']))\n    v_initial_y = initial_speed_m_s * sin(degree(params['angle']))\n\n    # Calculate the final velocity\n    g = 9.81  # Gravity in m/s\u00b2\n    v_final_y = v_initial_y - g * time_seconds\n    v_final = np.sqrt(v_initial_x**2 + v_final_y**2)\n\n    # Store the calculated final velocity converting back to the original speed unit if needed\n    final_velocity = v_final if params['unitsSpeed'] == 'm/s' else v_final * (3600 / 1000)\n\n    # Store results\n    correct_answers['final_velocity'] = round(final_velocity, 3)  # 3 significant figures\n\n    return {\n        'params': params,\n        'correct_answers': correct_answers,\n        'nDigits': 3,  # Decimal places\n        'sigfigs': 3   # Significant figures\n    }\n\n# Example usage\nif __name__ == \"__main__\":\n    problem_data = generate()\n    print(problem_data)\n```",
#   "solution_html": "<pl-question-panel>\n  <p> A projectile is launched at an angle of {{params.angle}} degrees with an initial speed of {{params.v}} {{params.unitsSpeed}}. After {{params.t}} seconds, determine the final velocity (in {{params.unitsSpeed}}) of the projectile.</p>\n</pl-question-panel>\n\n<pl-number-input answers-name=\"final_velocity\" comparison=\"sigfig\" digits=\"3\" label=\"$v_f=$ (in {{params.unitsSpeed}})\"></pl-number-input>\nExample Input: <pl-question-panel>\n  <p> A truck traveling at {{params.v}} {{params.unitsSpeed}} accelerates at a rate of {{params.a}} {{params.unitsAcceleration}} for {{params.t}} {{params.unitsTime}}. </p>\n  <p> What's the resulting speed of the truck in {{params.unitsSpeed}}?</p>\n</pl-question-panel>\n\n<pl-number-input answers-name=\"v\" comparison=\"sigfig\" digits=\"3\" label=\"Resulting speed ({{params.unitsSpeed}})\"></pl-number-input>\n\nExample Output: <pl-solution-panel>\n    <pl-hint level=\"1\" data-type=\"text\">\n        The final speed of the truck can be calculated using the formula: \\( v_f = v_i + at \\), where \\( v_i \\) is the initial speed, \\( a \\) is the acceleration, and \\( t \\) is the time.\n    </pl-hint>\n    <pl-hint level=\"2\" data-type=\"text\">\n        Substitute the given values into the formula: \\( v_f = {{params.v}} + {{params.a}} \\times {{params.t}} \\). Before using the formula ensure proper unit conversion.\n    </pl-hint>\n    <pl-hint level=\"3\" data-type=\"text\">\n        The resulting speed of the truck is \\( v_f = {correct_answers.v} {{params.unitsSpeed}} \\).\n    </pl-hint>\n</pl-solution-panel>",
#   "metadata": {
#     "title": "ProjectileMotionFinalVelocityCalculation",
#     "question": "What is the final velocity of a 2 kg projectile launched at 30 degrees with an initial speed of 20 m/s after 3 seconds?",
#     "stem": "Calculating the final velocity of a projectile under the influence of gravity after a certain time period.",
#     "topic": "Physics - Projectile Motion",
#     "tags": [
#       "Projectile Motion",
#       "Velocity",
#       "Physics",
#       "Kinematics",
#       "Free Fall"
#     ],
#     "prereqs": [
#       "Understanding of basic kinematics",
#       "Knowledge of trigonometry",
#       "Familiarity with gravity effects on motion"
#     ],
#     "isAdaptive": "True"
#   }
# }
# {
#   "question": "A block of mass 5 kg is sliding down a frictionless incline at an angle of 25 degrees. What is the acceleration of the block?",
#   "solution_guide": null,
#   "additional_instructions": null
# }
# {
#   "question_html": "<pl-question-panel>\n  <p> A block of mass {{params.mass}} kg is sliding down a frictionless incline at an angle of {{params.angle}} degrees.</p>\n  <p> What is the acceleration of the block (in {{params.unitsAcceleration}})?</p>\n</pl-question-panel>\n\n<pl-number-input answers-name=\"a\" comparison=\"sigfig\" digits=\"3\" label=\"Acceleration (in {{params.unitsAcceleration}})\"></pl-number-input>",
#   "server_js": "const math = require('mathjs');\n\nconst generate = () => {\n    const unitSystems = {\n        si: {\n            acceleration: 'm/s\u00b2',\n            mass: 'kg'\n        },\n        uscs: {\n            acceleration: 'ft/s\u00b2',\n            mass: 'lb'\n        }\n    };\n\n    // Dynamic Parameter Selection\n    const selectedSystem = math.randomInt(0, 2) === 0 ? 'si' : 'uscs';\n    const units = unitSystems[selectedSystem];\n\n    // Value Generation\n    const mass = math.randomInt(1, 101); // mass between 1 and 100 units\n    const angle = math.randomInt(1, 91); // angle between 1 and 90 degrees\n\n    // Solution Synthesis\n    // Calculate acceleration: a = g * sin(\u03b8)\n    const g = selectedSystem === 'si' ? 9.81 : 32.174; // gravitational constant in m/s\u00b2 or ft/s\u00b2\n    const acceleration = g * Math.sin(math.unit(angle, 'deg').toNumeric('rad'));\n\n    // Ensure results have the appropriate precision\n    const roundedAcceleration = math.round(acceleration, 3);\n\n    // Return the structured data\n    return {\n        params: {\n            mass: mass,\n            angle: angle,\n            unitsAcceleration: units.acceleration\n        },\n        correct_answers: {\n            a: roundedAcceleration\n        },\n        nDigits: 3, // Decimal places\n        sigfigs: 3 // Significant figures\n    };\n};\n\nmodule.exports = {\n    generate\n};\n",
#   "server_py": "```python\nimport numpy as np\nfrom sympy import symbols, solve, sin\n\n# Sample mass and incline data structure for unit testing\nmaterial_properties = {\n    'mass': [5],  # Sample mass in kg\n    'angle': [30], # Sample angle in degrees\n}\n\n# Dynamic selection of units\nUNIT_SYSTEM = ['m/s\u00b2', 'ft/s\u00b2']  # SI and USCS\n\n# Function to generate the module\n\ndef generate():\n    # Extracting dynamic parameters from the data structure\n    params = {\n        'mass': np.random.choice(material_properties['mass']),\n        'angle': np.random.choice(material_properties['angle']),\n        'unitsAcceleration': np.random.choice(UNIT_SYSTEM)\n    }\n\n    # Calculate acceleration: a = g * sin(theta)\n    g_si = 9.81  # m/s\u00b2\n    g_us = 32.2  # ft/s\u00b2\n    g = g_si if params['unitsAcceleration'] == 'm/s\u00b2' else g_us\n    angle_rad = np.deg2rad(params['angle'])\n    acceleration = g * np.sin(angle_rad)\n\n    # Creating the final dictionary of parameters and answers\n    output = {\n        'params': params,\n        'correct_answers': {\n            'a': round(acceleration, 3)\n        },\n        'nDigits': 3,  # Decimal places.\n        'sigfigs': 3   # Significant figures.\n    }\n\n    return output\n\n# Example of calling the generate function\nif __name__ == '__main__':\n    problem_data = generate()\n    print(problem_data)\n```\n```\nThe code defines a Python module that generates a physics problem related to an object sliding down an incline. It generates random parameters for the problem, computes acceleration, and provides results in SI or USCS units. The calculations maintain three significant figures or decimal places in compliance with the specifications provided.",
#   "solution_html": "<pl-question-panel>\n  <p> A block of mass {{params.mass}} {{params.unitsMass}} is sliding down a frictionless incline at an angle of {{params.angle}} degrees.</p>\n  <p> What is the acceleration of the block (in {{params.unitsAcceleration}})?</p>\n</pl-question-panel>\n\n<pl-number-input answers-name=\"a\" comparison=\"sigfig\" digits=\"{{nDigits}}\" label=\"Acceleration (in {{params.unitsAcceleration}})\"></pl-number-input>\n\n<pl-solution-panel>\n    <pl-hint level=\"1\" data-type=\"text\">\n        To determine the acceleration of the block on a frictionless incline, use the formula: \n        \\( a = g \\sin(\\theta) \\), where \\( g \\) is the acceleration due to gravity (approximately {{params.gravityValue}} in {{params.unitsAcceleration}}) and \\( \\theta \\) is the angle of the incline.\n    </pl-hint>\n    <pl-hint level=\"2\" data-type=\"text\">\n        Substitute the values: \\( a = {{params.gravityValue}} \\sin({{params.angle}}) \\).\n    </pl-hint>\n    <pl-hint level=\"3\" data-type=\"text\">\n        This calculation will give the acceleration of the block as it slides down the incline in units of {{params.unitsAcceleration}}.\n    </pl-hint>\n    <pl-hint level=\"4\" data-type=\"text\">\n        Ensure to keep track of significant figures based on the input provided (if applicable).\n    </pl-hint>\n    <pl-hint level=\"5\" data-type=\"text\">\n        The final result for acceleration will be dynamic based on the provided mass and angle of the incline: \\( {{correct_answers.a}} {{params.unitsAcceleration}} \\).\n    </pl-hint>\n</pl-solution-panel>",
#   "metadata": {
#     "title": "SlidingBlockAcceleration",
#     "question": "A block of mass 5 kg is sliding down a frictionless incline at an angle of 25 degrees. What is the acceleration of the block?",
#     "stem": "Understanding the motion of a block on an incline and the forces acting on it due to gravity.",
#     "topic": "Physics",
#     "tags": [
#       "mechanics",
#       "kinematics",
#       "inclined plane",
#       "acceleration",
#       "forces"
#     ],
#     "prereqs": [
#       "Basic concepts of physics",
#       "Newton's laws of motion",
#       "Trigonometry"
#     ],
#     "isAdaptive": "True"
#   }
# }
# {
#   "question": "Calculate the heat required to raise the temperature of 500g of water from 25\u00b0C to 75\u00b0C. Assume the specific heat of water is 4.18 J/g\u00b0C.",
#   "solution_guide": null,
#   "additional_instructions": null
# }
# {
#   "question_html": "<pl-question-panel>\n<p>\n  A {{params.materialName}} {{params.masslabel}} of {{params.m}} {{params.unitsMass}} is heated from an initial temperature of {{params.Ti}} {{params.unitsTemperature}} to {{params.Tf}} {{params.unitsTemperature}}.\n  The specific heat of {{params.materialName}} is {{params.Cp}} {{params.unitsCp}}.\n</p>\n</pl-question-panel>\n\n<p> How much heat was supplied to heat the {{params.masslabel}}? </p>\n<pl-number-input answers-name=\"Q\" comparison=\"sigfig\" digits=\"3\" label=\"Q  (in {{params.unitsHeat}})\"></pl-number-input>",
#   "server_js": "const math = require('mathjs');\n\nconst generate = () => {\n\n    // Define unit systems\n    const unitSystems = ['si', 'uscs'];\n\n    // Define parameter units for SI and USCS systems\n    const units = {\n        \"si\": {\n            \"mass\": \"kg\",\n            \"temperature\": \"\u00b0C\",\n            \"heat\": \"kJ\",\n            \"Cp\": \"kJ/kg\u00b0C\"\n        },\n        \"uscs\": {\n            \"mass\": \"lbs\",\n            \"temperature\": \"\u00b0F\",\n            \"heat\": \"BTU\",\n            \"Cp\": \"BTU/lb\u00b0F\"\n        }\n    };\n\n    // Randomly select a unit system\n    const unitSel = math.randomInt(0, 2); // 0 for SI, 1 for USCS\n\n    // Retrieve the corresponding unit labels\n    const currentUnits = units[unitSystems[unitSel]];\n\n    // Generate random values within typical ranges\n    const mass = unitSel === 0 ? math.round(math.random(1, 10), 2) : math.round(math.random(2, 20), 1); // kg or lbs\n    const Ti = unitSel === 0 ? math.round(math.random(20, 30), 1) : math.round(math.random(60, 90), 1); // \u00b0C or \u00b0F\n    const Tf = Ti + math.round(math.random(5, 15), 1); // \u00b0C or \u00b0F increase\n    const Cp = unitSel === 0 ? 0.5 : 0.25; // Example fixed values\n\n    // Calculate heat supplied Q = m * Cp * \u0394T\n    const Q = mass * Cp * (Tf - Ti);\n\n    // Format the result\n    const data = {\n        params: {\n            materialName: 'substance',  // Placeholder for actual material\n            masslabel: 'mass',\n            m: mass,\n            unitsMass: currentUnits.mass,\n            Ti: Ti,\n            Tf: Tf,\n            unitsTemperature: currentUnits.temperature,\n            Cp: Cp,\n            unitsCp: currentUnits.Cp,\n        },\n        correct_answers: {\n            Q: math.round(Q, 3),  // Round to 3 decimal places\n        },\n        nDigits: 3,  // Decimal places\n        sigfigs: 3   // Significant figures\n    };\n\n    console.log(data);\n    return data;\n}\n\nmodule.exports = {\n    generate\n};\n\ngenerate(); // Run the function to check the output",
#   "server_py": "```python\nimport numpy as np\nfrom sympy import symbols, Eq, solve\nimport pandas as pd\n\n# Sample material properties database to demonstrate functionality\ndb_properties = pd.DataFrame({\n    'material': ['air', 'water', 'iron'],\n    'Cp': [1.005, 4.186, 0.449],  # J/g\u00b0C\n\n})\n\n# Function to generate the problem parameters and solution\ndef generate():\n    # Dynamic Parameter Selection\n    # Choose a material from the database\n    material_properties = db_properties.sample(1).iloc[0]\n    materialName = material_properties['material']\n    \n    # Define units for parameters\n    unitsMass = 'g'\n    unitsTemperature = '\u00b0C'\n    unitsHeat = 'J'\n    \n    # Random values for the problem\n    mass = np.round(np.random.uniform(100, 500), 2)  # In grams\n    Ti = np.round(np.random.uniform(20, 25), 1)      # Initial temperature in \u00b0C\n    Tf = np.round(np.random.uniform(80, 100), 1)     # Final temperature in \u00b0C\n    Cp = material_properties['Cp']                # Specific heat\n\n    # Solution Synthesis\n    # Calculate heat supplied (Q = m * Cp * (Tf - Ti))\n    Q = mass * Cp * (Tf - Ti)  # J\n\n    # Result packaging\n    return {\n        'params': {\n            'materialName': materialName,\n            'masslabel': 'mass',\n            'm': mass,\n            'unitsMass': unitsMass,\n            'Ti': Ti,\n            'Tf': Tf,\n            'unitsTemperature': unitsTemperature,\n            'Cp': Cp,\n            'unitsCp': 'J/g\u00b0C'\n        },\n        'correct_answers': {\n            'Q': np.round(Q, 3)  # Heat supplied in Joules\n        },\n        'nDigits': 3,  # Decimal places\n        'sigfigs': 3   # Significant figures\n    }\n\n# Example usage\ngenerated_problem = generate()\nprint(generated_problem)\n```\n\nThis Python script will generate a problem regarding heating a material, using random values within specified ranges. The function outputs the parameters used, the calculated heat (Q), and specifies precision constraints for answers. The example database showcases simple material properties. The choice of specific heat (`Cp`) and other random values helps simulate real problem setups effectively.",
#   "solution_html": "<pl-question-panel>\n<p>\n  A {{params.materialName}} {{params.masslabel}} of {{params.m}} {{params.unitsMass}} is heated from an initial temperature of {{params.Ti}} {{params.unitsTemperature}} to {{params.Tf}} {{params.unitsTemperature}}.\n  The specific heat of {{params.materialName}} is {{params.Cp}} {{params.unitsCp}}.\n</p>\n</pl-question-panel>\n\n<p> How much heat was supplied to heat the {{params.masslabel}}? </p>\n<pl-number-input answers-name=\"Q\" comparison=\"sigfig\" digits=\"{{nDigits}}\" label=\"Q  (in {{params.unitsHeat}})\"></pl-number-input>\n\n<pl-solution-panel>\n    <pl-hint level=\"1\" data-type=\"text\"> Write the formula for heat transfer: Q = m * Cp * (Tf - Ti). </pl-hint>\n    <pl-hint level=\"2\" data-type=\"text\"> Substitute the known values into the formula: Q = {{params.m}} * {{params.Cp}} * ({{params.Tf}} - {{params.Ti}}). </pl-hint>\n    <pl-hint level=\"3\" data-type=\"text\"> Calculate the heat transfer using the provided values. Make sure the units are consistent. </pl-hint>\n    <pl-hint level=\"4\" data-type=\"text\"> Ensure that the results are reported in the correct units of heat transfer: {{params.unitsHeat}}. </pl-hint>\n    <pl-hint level=\"5\" data-type=\"text\"> Final answer: Q = {{correct_answers.Q}} {{params.unitsHeat}} </pl-hint>\n</pl-solution-panel>",
#   "metadata": {
#     "title": "HeatCalculationForWater",
#     "question": "Calculate the heat required to raise the temperature of 500g of water from 25\u00b0C to 75\u00b0C. Assume the specific heat of water is 4.18 J/g\u00b0C.",
#     "stem": "Calculating heat energy using the specific heat formula.",
#     "topic": "Thermodynamics",
#     "tags": [
#       "Heat",
#       "SpecificHeat",
#       "Thermodynamics",
#       "Water",
#       "EnergyCalculation"
#     ],
#     "prereqs": [
#       "Understanding of specific heat capacity",
#       "Basic thermodynamics principles"
#     ],
#     "isAdaptive": "True"
#   }
# }
